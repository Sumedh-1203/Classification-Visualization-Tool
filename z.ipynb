# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('Dataset1/test.csv')
df1.head()
# Out:
#          x1        x2  label
# 0 -0.310245 -5.890196    2.0
# 1 -4.147544 -1.970735    1.0
# 2  5.248462  1.019422    0.0
# 3  4.169801  2.378386    0.0
# 4 -2.737245 -0.156693    1.0

# %%
plt.scatter(df1['x1'], df1['x2'], c=df1['label'])
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar(label='label')
plt.show()

# %%
df2 = pd.read_csv('Dataset2/test.csv')
df2.head()
# Out:
#           x1         x2  label
# 0  -8.081396  -2.932348    0.0
# 1 -15.083647   2.691775    1.0
# 2  12.911330  -5.544052    0.0
# 3  -1.610802  13.720002    1.0
# 4   2.023606  -5.891770    1.0

# %%
plt.scatter(df2['x1'], df2['x2'], c=df2['label'])
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar(label='label')
plt.show()
